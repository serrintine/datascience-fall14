# %%
# Render our plots inline
# %pylab inline

# Import several libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('crime_incidents_2013.csv', usecols = ["REPORTDATETIME", "SHIFT", "OFFENSE", "METHOD", "DISTRICT"], parse_dates = ['REPORTDATETIME'])
data.head()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
#        REPORTDATETIME     SHIFT    OFFENSE  METHOD DISTRICT
# 0 2013-04-16 00:00:00  MIDNIGHT   HOMICIDE   KNIFE    FIRST
# 1 2013-06-05 00:00:00  MIDNIGHT  SEX ABUSE   KNIFE   FOURTH
# 2 2013-07-08 00:00:00  MIDNIGHT  SEX ABUSE  OTHERS    THIRD
# 3 2013-04-08 00:00:00  MIDNIGHT  SEX ABUSE  OTHERS    THIRD
# 4 2013-02-27 00:00:00  MIDNIGHT  SEX ABUSE  OTHERS   SECOND

# %%
data.OFFENSE.value_counts().plot(kind='bar')
